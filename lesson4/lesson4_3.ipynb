# %%
#for迴圈

total = 0

for i in range(1,11):
    total += i
total
# Out:
# 55

# %%
import random

while random.randint(1,10) != 5:
    print("不等於5")
print("等於5")
# Out:
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 等於5

# %%
import random


while True:
    if random.randint(1,10) == 5:
        break
    print("不等於5")
print("等於5")
# Out:
# 等於5
