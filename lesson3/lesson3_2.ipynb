# %%
print("Hello Python!")
# Out:
# Hello Python!

# %%
a = 10
b = 3
print(a + b)   # 13
print(a / b)   # 3.333...（浮點數除法）
print(a // b)  # 3     （整數除法，取商）
print(a % b)   # 1     （取餘數）
print(a ** b)  # 1000  （次方）
# Out:
# 13
# 3.3333333333333335
# 3
# 1
# 1000

# %%
m1 = 5
m2 = 5.0
m3 = '5.0'
m4 = "5.0"
m5 = True
print(type(m1))
print(type(m2))
print(type(m3))
print(type(m4))
print(type(m5))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
print(5 + 5)
print(5 + 5.0)
# print(5 + '5') 這是錯的,數值+字串
print('5' + '5')
print('=' * 20)
# Out:
# 10
# 10.0
# 55
# ====================

# %%
apple = 7
orange = 10

print('apple有5個,orange有10個')
print("apple有" + str(apple) + "個,orange有" + str(orange) + "個")
print(f"apple有{apple}個,orange有{orange}個") #字串插補
# Out:
# apple有5個,orange有10個
# apple有7個,orange有10個
# apple有7個,orange有10個

# %%
chinese = 55
chinese = chinese + 7
print(chinese)
# Out:
# 62

# %%
chinese = 55
chinese += 7 # 複合指定運算子
print(chinese)
# Out:
# 62

# %%
english = 10
english += 15
english *= 4
print(english)
# Out:
# 100

# %%
age = int(input("請輸入年齡"))
if age >= 18:
    print("可以考駕照")
    print("=================")
else:
    print("不可以考駕照")
    print("=================")
    
print("應用程式結束")
# Out:
# 不可以考駕照
# =================
# 應用程式結束
